# %% [markdown]
# <h1 align = "center" > CYBERSECURITY ATTACK TYPE PREDICTION ML </h1>

# %% [markdown]
# # Cybersecurity Attack Classification
# **Dataset:** Cybersecurity Attacks (40,000 rows, 25 columns)
# **Goal:** Classify network events by attack type using traffic features
# **Target:** Attack Type (DDoS, Intrusion, Malware)
#
# ## 1. Data Loading and Inspection
# ### 1.1 Load dataset
# ### 1.2 Inspect basics — shape, columns, head, info, missing values
#
# ## 2. Data Cleaning and Preparation
# ### 2.1 Split numeric vs categorical columns
# ### 2.2 Fix data types — Timestamp to datetime, coerce numeric strings
# ### 2.3 Drop duplicate rows
# ### 2.4 Handle missing values — median for numeric, mode for categorical
#
# ## 3. Target Variable Analysis
# ### 3.1 Select target variable — Attack Type
# ### 3.2 Plot target distribution
# ### 3.3 Assess class imbalance
#
# ## 4. Exploratory Data Analysis
# ### 4.1 Severity Level
# ### 4.2 Anomaly Score
# ### 4.3 Traffic Type
# ### 4.4 Protocol
# ### 4.5 Packet Length
#
# ## 5. Attack Pattern Exploration
# ### 5.1 Attack Type vs Network Segment
# ### 5.2 Attack Type vs Traffic Type
# ### 5.3 Attack Type vs Protocol
#
# ## 6. Correlation and Insights
# ### 6.1 Correlation heatmap — numeric features only
# ### 6.2 Strongest relationships — findings
#
# ## 7. Findings and Feature Selection
# ### 7.1 Key patterns found
# ### 7.2 Interesting insights
# ### 7.3 Candidate prediction features
#
# ## 8. Feature Engineering
# ### 8.1 Define X and y
# ### 8.2 Remove leakage columns — Attack Signature, IDS/IPS Alerts, Malware Indicators
# ### 8.3 One-hot encode categorical columns
# ### 8.4 Apply StandardScaler to numeric features
#
# ## 9. Data Splitting and Validation
# ### 9.1 Train-test split — 80/20, stratified
# ### 9.2 5-fold cross-validation
# ### 9.3 Record baseline cross-validation score
#
# ## 10. Baseline Model — Logistic Regression
# ### 10.1 Train Logistic Regression
# ### 10.2 Evaluate — accuracy, precision, recall, F1
#
# ## 11. Preprocessing Review
# ### 11.1 Document all preprocessing decisions
# ### 11.2 Document leakage checks
#
# ## 12. Decision Tree Model
# ### 12.1 Train Decision Tree
# ### 12.2 Evaluate and compare vs baseline
# ### 12.3 Feature importance — top 10
#
# ## 13. Random Forest Model
# ### 13.1 Train Random Forest
# ### 13.2 Tune n_estimators
# ### 13.3 Tune max_depth
# ### 13.4 Model comparison table — Logistic Regression vs Decision Tree vs Random Forest
#
# ## 14. Finalisation and Portfolio Output
# ### 14.1 Error analysis — which classes does the model struggle with?
# ### 14.2 Lock final model and results
# ### 14.3 Save visuals to /images
# ### 14.4 Write report.md
# ### 14.5 Write README.md
# ### 14.6 Restart kernel — run all cells, zero errors
# ### 14.7 Push to GitHub

# %% [markdown]
# #### 1.1 importing libaries

# %%
import numpy as np
import pandas as pd
import warnings 
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#### 1.2 Loading the dataset

# %%
df = pd.read_csv("cybersecurity_attacks.csv")

# %%
df
# Out:
#                  Timestamp Source IP Address Destination IP Address  \
# 0      2023-05-30 06:33:58     103.216.15.12           84.9.164.252
# 1      2020-08-26 07:08:30    78.199.217.198         66.191.137.154
# 2      2022-11-13 08:23:25      63.79.210.48          198.219.82.17
# 3      2023-07-02 10:38:46     163.42.196.10        101.228.192.255
# 4      2023-07-16 13:11:07     71.166.185.76        189.243.174.238
# ...                    ...               ...                    ...
# 39995  2023-05-26 14:08:42      26.36.109.26         121.100.75.240
# 39996  2023-03-27 00:38:27      17.21.163.81         196.108.134.78
# 39997  2022-03-31 01:45:49     162.35.217.57            98.107.0.15
# 39998  2023-09-22 18:32:38    208.72.233.205         173.79.112.252
# 39999  2023-10-10 11:59:52     14.102.21.108           109.198.45.7
#
#        Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 0            31225             17616     ICMP            503        Data
# ...

# %% [markdown]
# #### 1.2 Reconigsie the varible in the dataset

# %% [markdown]
# ## Dataset Variables Explanation
#
# - Timestamp: Date and time when the network event occurred
# - Source IP Address: IP address where the traffic originated
# - Destination IP Address: IP address where the traffic was sent to
# - Source Port: Port number used by the source device
# - Destination Port: Port number used by the destination service
# - Protocol: Type of network protocol used (TCP, UDP, ICMP, etc.)
# - Packet Length: Size of the data packet being transmitted
# - Packet Type: Type of packet (Data or Control)
# - Traffic Type: Type of network service (HTTP, DNS, FTP, etc.)
# - Payload Data: Actual content/data carried in the packet
# - Action Taken: Security response (Logged, Blocked, Ignored)
# - Severity Level: Risk level of the event (Low, Medium, High)
# - User Information: User associated with the network activity
# - Device Information: Device/browser/OS details generating the traffic
# - Network Segment: Internal network zone (e.g., Segment A, B, C)
# - Geo-location Data: Physical location of the IP address
# - Proxy Information: Proxy IP if traffic is routed through a proxy
# - Firewall Logs: Firewall recording status of the event
# - IDS/IPS Alerts: Intrusion Detection/Prevention system alerts
# - Log Source: Origin of the log data (Firewall, Server, etc.)

# %% [markdown]
# 1.3 Overview the dataset

# %%
df.shape
# Out:
# (40000, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               40000 non-null  object
#  1   Source IP Address       40000 non-null  object
#  2   Destination IP Address  40000 non-null  object
#  3   Source Port             40000 non-null  int64
#  4   Destination Port        40000 non-null  int64
#  5   Protocol                40000 non-null  object
#  6   Packet Length           40000 non-null  int64
#  7   Packet Type             40000 non-null  object
#  8   Traffic Type            40000 non-null  object
#  9   Payload Data            40000 non-null  object
#  10  Malware Indicators      20000 non-null  object
#  11  Anomaly Scores          40000 non-null  float64
#  12  Alerts/Warnings         19933 non-null  object
#  13  Attack Type             40000 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                     0
# Source IP Address             0
# Destination IP Address        0
# Source Port                   0
# Destination Port              0
# Protocol                      0
# Packet Length                 0
# Packet Type                   0
# Traffic Type                  0
# Payload Data                  0
# Malware Indicators        20000
# Anomaly Scores                0
# Alerts/Warnings           20067
# Attack Type                   0
# Attack Signature              0
# Action Taken                  0
# Severity Level                0
# User Information              0
# Device Information            0
# Network Segment               0
# Geo-location Data             0
# Proxy Information         19851
# Firewall Logs             19961
# IDS/IPS Alerts            20050
# Log Source                    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               40000 non-null  object
#  1   Source IP Address       40000 non-null  object
#  2   Destination IP Address  40000 non-null  object
#  3   Source Port             40000 non-null  int64
#  4   Destination Port        40000 non-null  int64
#  5   Protocol                40000 non-null  object
#  6   Packet Length           40000 non-null  int64
#  7   Packet Type             40000 non-null  object
#  8   Traffic Type            40000 non-null  object
#  9   Payload Data            40000 non-null  object
#  10  Malware Indicators      20000 non-null  object
#  11  Anomaly Scores          40000 non-null  float64
#  12  Alerts/Warnings         19933 non-null  object
#  13  Attack Type             40000 non-null  object
# ...

# %% [markdown]
# ## Conclusion
#
# This dataset comprises 40,000 cybersecurity network traffic records across 25 distinct features, encompassing foundational network data (e.g., IP addresses, protocols) and security indicators (e.g., attack types, anomaly scores). While the majority of the dataset is complete, targeted imputation will be required for missing values within certain security-related fields. With a rich blend of both numerical and categorical variables, this dataset provides a robust foundation for deep network traffic analysis and the development of predictive machine learning models following proper data preprocessing.
